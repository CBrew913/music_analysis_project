# %% [markdown]
# # Machine Learning Linear Regression: Train Test Split
# ## POPULARITY & PERCENTAGE OF BAD WORDS

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
genres_df = pd.read_csv(Path('music_genres.csv')) 
print(genres_df.shape)
genres_df.head()
# Out:
# (546, 5)
#    pop_rating      artist                 title            genre  \
# 0          83       Train      Hey, Soul Sister       neo mellow
# 1          82      Eminem  Love The Way You Lie  detroit hip hop
# 2          80       Kesha               TiK ToK        dance pop
# 3          79   Lady Gaga           Bad Romance        dance pop
# 4          78  Bruno Mars  Just the Way You Are              pop
#
#    perc_bad_words
# 0        0.000000
# 1        0.819672
# 2        0.000000
# 3        0.959693
# 4        0.000000

# %%
X = genres_df.pop_rating.values.reshape(-1, 1)
print(X)
# Out:
# [[83]
#  [82]
#  [80]
#  [79]
#  [78]
#  [77]
#  [77]
#  [77]
#  [76]
#  [73]
#  [73]
#  [73]
#  [73]
#  [73]
#  [72]
#  [72]
#  [71]
#  [70]
#  [69]
#  [69]
#  [68]
#  [66]
#  [66]
#  [65]
#  [65]
#  [65]
#  [64]
#  [63]
#  [63]
#  [62]
#  [62]
#  [62]
#  [62]
#  [62]
#  [62]
#  [61]
#  [59]
#  [59]
#  [58]
#  [57]
#  [57]
#  [56]
#  [56]
#  [55]
#  [52]
#  [52]
#  [49]
#  [33]
#  [ 0]
#  [81]
#  [80]
#  [79]
#  [76]
#  [75]
#  [75]
#  [74]
#  [73]
#  [73]
#  [72]
#  [72]
#  [72]
#  [72]
#  [69]
#  [69]
#  [69]
#  [68]
#  [67]
#  [67]
#  [66]
#  [65]
#  [64]
#  [64]
#  [64]
#  [63]
#  [63]
#  [63]
#  [61]
#  [61]
#  [59]
#  [59]
#  [58]
#  [58]
#  [54]
#  [50]
#  [46]
#  [38]
#  [38]
#  [31]
#  [27]
#  [25]
#  [66]
#  [80]
#  [79]
#  [79]
#  [79]
#  [78]
#  [77]
#  [76]
#  [76]
#  [76]
#  [75]
#  [74]
#  [74]
#  [73]
#  [73]
#  [73]
#  [72]
#  [72]
#  [72]
#  [72]
#  [71]
#  [71]
#  [69]
#  [68]
#  [68]
#  [67]
#  [66]
#  [65]
#  [65]
#  [61]
#  [59]
#  [57]
#  [54]
#  [38]
#  [ 0]
# ...

# %%
y = genres_df.perc_bad_words
print(y)
# Out:
# 0      0.000000
# 1      0.819672
# 2      0.000000
# 3      0.959693
# 4      0.000000
#          ...
# 541    0.000000
# 542    0.000000
# 543    0.000000
# 544    0.000000
# 545    0.487805
# Name: perc_bad_words, Length: 546, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X, y, random_state = 0)

# %%
#fitting Simple Regression to training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#predecting the test set results
y_pred = regressor.predict(X_test)
print(y_pred.shape)
# Out:
# (137,)

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.xlabel('Popularity of Song')
plt.ylabel('Percentage of Bad Words')
plt.show()

# %%
print(regressor.coef_)
# Out:
# [0.00020919]

# %%
print(regressor.intercept_)
# Out:
# 0.1927143639895444
